# %% [markdown]
# # Campo de gravidade no mundo

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import xarray as xr

# %%
import harmonica as hm

# %%
notebook_name = '1.2. gravity_earth.ipynb'

# %% [markdown]
# ### Plot Style

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Carregando os dados de gravidade

# %%
def fetch_dataset(fname):
    data = xr.open_dataset(fname)
    # Capture attributes dict because it's removed after converting the data to
    # float64
    attrs = data.attrs.copy()
    # The data are stored as ints and data as float32 to save space on the
    # data file. Cast them to float64 to avoid integer division errors.
    data = data.astype("float64")
    data.attrs = attrs
    return data

# %%
filename = 'data_set/gravity_05deg_EIGEN-6C4.nc'

# %%
data = fetch_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 361, longitude: 721)
# Coordinates:
#   * latitude   (latitude) float64 90.0 89.5 89.0 88.5 ... -89.0 -89.5 -90.0
#   * longitude  (longitude) float64 -180.0 -179.5 -179.0 ... 179.0 179.5 180.0
# Data variables:
#     gravity    (latitude, longitude) float64 9.832e+05 9.832e+05 ... 9.824e+05
# Attributes:
#     description:  Gravity Earth data

# %%
lon = data.longitude

# %%
lat = data.latitude

# %%
grav = data.gravity

# %% [markdown]
# ## Campo gravitacional (Mundo)

# %%
title_font = 18
bottom_font = 15
plt.figure(figsize=(10,10), tight_layout=True)

projection = ccrs.Mollweide()
ax = plt.axes(projection=projection)
ax.set_global()
ax.coastlines()
ax.set_title('Gravidade (mGal)',size=title_font)
pg = ax.contourf(lon,
                 lat,
                 grav,100,transform=ccrs.PlateCarree(),cmap='RdBu_r')
cb = plt.colorbar(pg, orientation="horizontal", pad=0.01, aspect=50, shrink=1.1)
cb.ax.tick_params(labelsize=bottom_font)

plt.show()
